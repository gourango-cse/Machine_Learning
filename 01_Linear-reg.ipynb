# %%
import warnings
warnings.filterwarnings("ignore")
# predict time
import pandas as pd
import numpy as np
import math
from sklearn import linear_model
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv("/media/gourango/EDUCARE/M.Tech Assignment/Salary_Data.csv")
#print(df)
#X = df[['Weather','Roadsurface','Congestion']]
#y = df[['Velocity']]
X=df.iloc[:,0:1]
y=df.iloc[:,1:2]
#print(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3)

from sklearn.linear_model import LinearRegression
clf = LinearRegression()

clf.fit(X_train,y_train)
clf.fit(X,y)


#print(X)

#print(y)
# Out:
# LinearRegression()

# %%
#print(X)


#input()
# Create and train the model
model = LinearRegression()
model.fit(X,y)

# New data point for prediction (single sample, 1D array)
new_data = np.array([2.5])  # This is a 1D array

# Reshape the data to 2D for prediction (1 sample with 1 feature)
new_data = new_data.reshape(-1, 1)  # Reshaping to 2D array

# Predict the target for the new data
predicted_value = model.predict(new_data)

print(f"Predicted value for {new_data.flatten()[0]}: {predicted_value[0]}")
# Out:
# Predicted value for 2.5: [49417.10600231]

# %%
# Get the slope (coefficient) and intercept
slope = model.coef_[0]
intercept = model.intercept_


# Print the slope and intercept
print(f"Slope (m): {slope}")
print(f"Intercept (b): {intercept}")

y_pred = model.predict(X)

# Plotting the data points
plt.scatter(X, y, color='blue', label='Data Points')

# Plotting the regression line
plt.plot(X,y_pred)


# Add labels and title
plt.xlabel('Feature (X)')
plt.ylabel('Target (y)')
plt.title('Simple Linear Regression')

# Show the legend
plt.legend()

# Show the plot
plt.show()
# Out:
# Slope (m): [9449.96232146]
# Intercept (b): [25792.20019867]
