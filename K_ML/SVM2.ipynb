# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,predictions)
print(accuracy)
# Out:
# 0.341991341991342

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,predictions)
tp=cm[0][0]
fp=cm[0][1]
fn=cm[1][0]
tn=cm[1][1]
print(tp)
print(fp)
print(fn)
print(tn)
accuracy1=(tp+tn)/(tp+fp+tn+fn)
print(accuracy1)

# %%
data = [[1,89,66,23,94,28.1,0.167,21]]
prediction = clf.predict(data)
print ("prediction for new data:",prediction)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# Define the SVM class
class SVM:
    def __init__(self, learning_rate=0.001, n_iters=1000):
        self.lr = learning_rate
        self.n_iters = n_iters
        self.w = None
        self.b = None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.w = np.zeros(n_features)
        self.b = 0

        # Convert y to {-1, 1} if not already
        y_ = np.where(y <= 0, -1, 1)

        for _ in range(self.n_iters):
            for idx, x_i in enumerate(X):
                condition = y_[idx] * (np.dot(x_i, self.w) + self.b) >= 1
                if condition:
                    self.w -= self.lr * (2 * self.w)  # Apply regularization
                else:
                    self.w -= self.lr * (2 * self.w - np.dot(x_i, y_[idx]))
                    self.b -= self.lr * y_[idx]

    def predict(self, X):
        linear_output = np.dot(X, self.w) + self.b
        return np.sign(linear_output).astype(int)

# Load dataset
data = pd.read_csv('diabetes.csv')
#data = data.drop('Patient Name', axis=1)  # Drop irrelevant columns
X = data.drop(columns='Outcomes').values
y = data['Outcomes'].values

# Ensure target labels are in {1, -1} format
y = np.where(y <= 0, -1, 1)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Train the SVM
clf = SVM(learning_rate=0.001, n_iters=1000)
clf.fit(X_train, y_train)

# Predict on the test set
predictions = clf.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy:.4f}")

# Confusion matrix
cm = confusion_matrix(y_test, predictions)
tp = cm[0, 0]
fp = cm[0, 1]
fn = cm[1, 0]
tn = cm[1, 1]

print(f"True Positives (TP): {tp}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
print(f"True Negatives (TN): {tn}")


# Verify accuracy manually
manual_accuracy = (tp + tn) / (tp + fp + fn + tn)
print(f"Manual Accuracy: {manual_accuracy:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 38
#      36 data = pd.read_csv('diabetes.csv')
#      37 #data = data.drop('Patient Name', axis=1)  # Drop irrelevant columns
# ---> 38 X = data.drop(columns='Outcomes').values
#      39 y = data['Outcomes'].values
#      41 # Ensure target labels are in {1, -1} format
#
# File C:\python\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
# ...

# %%
# Function for user input validation
def validate_input(clf, feature_names):
    print("\nEnter values for validation:")
    input_features = []
    for feature in feature_names:
        value = float(input(f"Enter value for {feature}: "))
        input_features.append(value)

    input_features = np.array(input_features).reshape(1, -1)  # Reshape for prediction
    prediction = clf.predict(input_features)
    result = "Positive (1)" if prediction[0] == 1 else "Negative (-1)"
    print(f"Prediction: {result}")

# Feature names (excluding target column)
feature_names = data.drop(columns='Outcome').columns

# Allow user to input data for validation
validate_input(clf, feature_names)
# Out:
# Enter values for validation:
# Enter value for Pregnancies:  0
# Enter value for Glucose:  137
# Enter value for BloodPressure:  40
# Enter value for SkinThickness:  35
# Enter value for Insulin:  168
# Enter value for BMI:  43.1
# Enter value for DiabetesPedigreeFunction:  2.288
# Enter value for Age:  33
# Prediction: Negative (-1)

# %%
data = pd.read_csv('iris.csv')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# Define the SVM class
class SVM:
    def __init__(self, learning_rate=0.001, n_iters=1000):
        self.lr = learning_rate
        self.n_iters = n_iters
        self.w = None
        self.b = None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.w = np.zeros(n_features)
        self.b = 0

        # Convert y to {-1, 1} if not already
        y_ = np.where(y <= 0, -1, 1)

        for _ in range(self.n_iters):
            for idx, x_i in enumerate(X):
                condition = y_[idx] * (np.dot(x_i, self.w) + self.b) >= 1
                if condition:
                    self.w -= self.lr * (2 * self.w)  # Apply regularization
                else:
                    self.w -= self.lr * (2 * self.w - np.dot(x_i, y_[idx]))
                    self.b -= self.lr * y_[idx]

    def predict(self, X):
        linear_output = np.dot(X, self.w) + self.b
        return np.sign(linear_output).astype(int)

# %%
# Load dataset
data = pd.read_csv('diabetes.csv')
#data = data.drop('Patient Name', axis=1)  # Drop irrelevant columns
X = data.drop(columns='Outcome').values
y = data['Outcome'].values

# Ensure target labels are in {1, -1} format
#y = np.where(y <= 0, -1, 1)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
print("Class distribution in y_train:", np.bincount(y_train))
# Out:
# Class distribution in y_train: [343 194]

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42)
X_resampled, y_resampled = rus.fit_resample(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from imblearn.under_sampling import RandomUnderSampler
#       3 rus = RandomUnderSampler(random_state=42)
#       4 X_resampled, y_resampled = rus.fit_resample(X_train, y_train)
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

class SVM:
    def __init__(self, learning_rate=0.01, n_iters=1000):
        self.lr = learning_rate
        self.n_iters = n_iters
        self.w = None
        self.b = None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.w = np.zeros(n_features)
        self.b = 0
        
        for _ in range(self.n_iters):
            for idx, x_i in enumerate(X):
                condition = y[idx] * (np.dot(x_i, self.w) + self.b) >= 1
                if condition:
                    # Update weights (regularization term)
                    self.w -= self.lr * (2 * self.w)
                else:
                    # Update weights with hinge loss contribution
                    self.w -= self.lr * (2 * self.w - np.dot(x_i, y[idx]))
                    self.b -= self.lr * y[idx]

    def predict(self, X):
        prediction = np.dot(X, self.w) + self.b
        return np.sign(prediction).astype(int)

# Load dataset
data = pd.read_csv('PatientDetails_Classification.csv')
data = data.drop('Patient Name', axis=1)

# Prepare features and target variable
X = data.drop(columns='TARGET').values
y = data['TARGET'].values

# Split dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train SVM classifier
clf = SVM()
clf.fit(X_train, y_train)

# Predict on test set
predictions = clf.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy:.4f}")

# Confusion Matrix and TP, FP, FN, TN
cm = confusion_matrix(y_test, predictions)
tp, fp, fn, tn = cm.ravel()

# Print confusion matrix values
print(f"True Positives (TP): {tp}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
print(f"True Negatives (TN): {tn}")

# Calculate accuracy using confusion matrix
accuracy = (tp + tn) / (tp + fp + tn + fn)
print(f"Calculated Accuracy from Confusion Matrix: {accuracy:.4f}")
# Out:
# Accuracy: 0.8750
# True Positives (TP): 0
# False Positives (FP): 1
# False Negatives (FN): 0
# True Negatives (TN): 7
# Calculated Accuracy from Confusion Matrix: 0.8750

# %%
# Take custom input for testing the model
def take_input_and_predict():
    print("\nPlease enter the feature values for a new patient (separated by commas):")
    features = input().split(',')
    
    # Convert the input features to a numpy array
    features = np.array([float(f) for f in features])
    
    # Reshape the input to match the expected shape (1 sample, n_features)
    features = features.reshape(1, -1)
    
    # Predict the class
    prediction = clf.predict(features)
    print(f"The predicted class is: {prediction[0]}")

# Call the function to take input and predict
take_input_and_predict()
# Out:
# Please enter the feature values for a new patient (separated by commas):
#  10,139,80,0,0,27.1,1.441,57
# The predicted class is: 1

# %%
# Load dataset
data = pd.read_csv('PatientDetails_Classification.csv')
data = data.drop('Patient Name', axis=1)
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  TARGET
# 0                     0.627   50       1
# 1                     0.351   31       0
# 2                     0.672   32       1
# 3                     0.167   21       0
# 4                     2.288   33       1
